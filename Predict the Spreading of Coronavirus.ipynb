# %%
#Source Dataset
#https://www.kaggle.com/sudalairajkumar/novel-corona-virus-2019-dataset/download/uMF6QnlPB7ScS6BxTw1I%2Fversions%2FW8pK1hjKtuCpIstEfKKm%2Ffiles%2Fcovid_19_data.csv?datasetVersionNumber=42

# %% [markdown]
# # Pandas Read & Write

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.0.3'

# %%
pd.read_csv("COVID19_line_list_data.csv")
# Out:
#         id  case_in_country reporting date  Unnamed: 3  \
# 0        1              NaN      1/20/2020         NaN
# 1        2              NaN      1/20/2020         NaN
# 2        3              NaN      1/21/2020         NaN
# 3        4              NaN      1/21/2020         NaN
# 4        5              NaN      1/21/2020         NaN
# ...    ...              ...            ...         ...
# 1080  1081              2.0      2/25/2020         NaN
# 1081  1082              1.0      2/24/2020         NaN
# 1082  1083              1.0      2/26/2020         NaN
# 1083  1084              1.0      2/25/2020         NaN
# 1084  1085              1.0      2/25/2020         NaN
#
#                                                 summary             location  \
# 0     First confirmed imported COVID-19 pneumonia pa...  Shenzhen, Guangdong
# 1     First confirmed imported COVID-19 pneumonia pa...             Shanghai
# ...

# %%
COV19_WORLD = pd.read_csv("COVID19_line_list_data.csv")

# %%
# Print Dataframe
COV19_WORLD
# Out:
#         id  case_in_country reporting date  Unnamed: 3  \
# 0        1              NaN      1/20/2020         NaN
# 1        2              NaN      1/20/2020         NaN
# 2        3              NaN      1/21/2020         NaN
# 3        4              NaN      1/21/2020         NaN
# 4        5              NaN      1/21/2020         NaN
# ...    ...              ...            ...         ...
# 1080  1081              2.0      2/25/2020         NaN
# 1081  1082              1.0      2/24/2020         NaN
# 1082  1083              1.0      2/26/2020         NaN
# 1083  1084              1.0      2/25/2020         NaN
# 1084  1085              1.0      2/25/2020         NaN
#
#                                                 summary             location  \
# 0     First confirmed imported COVID-19 pneumonia pa...  Shenzhen, Guangdong
# 1     First confirmed imported COVID-19 pneumonia pa...             Shanghai
# ...

# %%
COV19_WORLD.head()
# Out:
#    id  case_in_country reporting date  Unnamed: 3  \
# 0   1              NaN      1/20/2020         NaN
# 1   2              NaN      1/20/2020         NaN
# 2   3              NaN      1/21/2020         NaN
# 3   4              NaN      1/21/2020         NaN
# 4   5              NaN      1/21/2020         NaN
#
#                                              summary             location  \
# 0  First confirmed imported COVID-19 pneumonia pa...  Shenzhen, Guangdong
# 1  First confirmed imported COVID-19 pneumonia pa...             Shanghai
# 2  First confirmed imported cases in Zhejiang: pa...             Zhejiang
# 3  new confirmed imported COVID-19 pneumonia in T...              Tianjin
# 4  new confirmed imported COVID-19 pneumonia in T...              Tianjin
#
#   country  gender   age symptom_onset  ...  recovered symptom  \
# 0   China    male  66.0      01/03/20  ...          0     NaN
# 1   China  female  56.0     1/15/2020  ...          0     NaN
# ...

# %%
COV19_WORLD.head(3)
# Out:
#    id  case_in_country reporting date  Unnamed: 3  \
# 0   1              NaN      1/20/2020         NaN
# 1   2              NaN      1/20/2020         NaN
# 2   3              NaN      1/21/2020         NaN
#
#                                              summary             location  \
# 0  First confirmed imported COVID-19 pneumonia pa...  Shenzhen, Guangdong
# 1  First confirmed imported COVID-19 pneumonia pa...             Shanghai
# 2  First confirmed imported cases in Zhejiang: pa...             Zhejiang
#
#   country  gender   age symptom_onset  ...  recovered symptom  \
# 0   China    male  66.0      01/03/20  ...          0     NaN
# 1   China  female  56.0     1/15/2020  ...          0     NaN
# 2   China    male  46.0      01/04/20  ...          0     NaN
#
#                                               source  \
# 0               Shenzhen Municipal Health Commission
# 1  Official Weibo of Shanghai Municipal Health Co...
# ...

# %%
COV19_WORLD.tail()
# Out:
#         id  case_in_country reporting date  Unnamed: 3  \
# 1080  1081              2.0      2/25/2020         NaN
# 1081  1082              1.0      2/24/2020         NaN
# 1082  1083              1.0      2/26/2020         NaN
# 1083  1084              1.0      2/25/2020         NaN
# 1084  1085              1.0      2/25/2020         NaN
#
#                                                 summary     location  \
# 1080  new COVID-19 patient confirmed in Austria: 24,...    Innsbruck
# 1081  new COVID-19 patient confirmed in Afghanistan:...  Afghanistan
# 1082  new COVID-19 patient confirmed in Algeria: mal...      Algeria
# 1083  new COVID-19 patient confirmed in Croatia: mal...      Croatia
# 1084  new COVID-19 patient confirmed in Switzerland:...         Bern
#
#           country gender   age symptom_onset  ...  recovered symptom  \
# 1080      Austria    NaN  24.0           NaN  ...          0     NaN
# 1081  Afghanistan    NaN  35.0           NaN  ...          0     NaN
# ...

# %%
COV19_WORLD.tail(3)
# Out:
#         id  case_in_country reporting date  Unnamed: 3  \
# 1082  1083              1.0      2/26/2020         NaN
# 1083  1084              1.0      2/25/2020         NaN
# 1084  1085              1.0      2/25/2020         NaN
#
#                                                 summary location      country  \
# 1082  new COVID-19 patient confirmed in Algeria: mal...  Algeria      Algeria
# 1083  new COVID-19 patient confirmed in Croatia: mal...  Croatia      Croatia
# 1084  new COVID-19 patient confirmed in Switzerland:...     Bern  Switzerland
#
#      gender   age symptom_onset  ...  recovered symptom  \
# 1082   male   NaN           NaN  ...          0     NaN
# 1083   male   NaN           NaN  ...          0     NaN
# 1084   male  70.0     2/17/2020  ...          0     NaN
#
#                         source  \
# 1082  South China Morning Post
# 1083                   Reuters
# 1084                   Reuters
#
# ...

# %%
COV19_WORLD.sample(5)
# Out:
#       id  case_in_country reporting date  Unnamed: 3  \
# 418  419            183.0      2/27/2020         NaN
# 385  386            150.0      2/26/2020         NaN
# 148  149              NaN      1/25/2020         NaN
# 189  190              NaN      1/27/2020         NaN
# 356  357            121.0      2/23/2020         NaN
#
#                                                summary          location  \
# 418  new confirmed COVID-19 patient in Japan: Hokka...          Hokkaido
# 385  new confirmed COVID-19 patient in Japan: Chiba...  Chiba Prefecture
# 148  new confirmed COVID-19 pneumonia patient in Xi...          Xinjiang
# 189  new confirmed COVID-19 pneumonia patient 01/27...           Shaanxi
# 356  new confirmed COVID-19 patient in Japan: Hokka...          Hokkaido
#
#     country gender   age symptom_onset  ...  recovered       symptom  \
# 418   Japan   male   5.0     2/21/2020  ...          0  fever, cough
# ...

# %%
COV19_WORLD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1085 entries, 0 to 1084
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     1085 non-null   int64
#  1   case_in_country        888 non-null    float64
#  2   reporting date         1084 non-null   object
#  3   Unnamed: 3             0 non-null      float64
#  4   summary                1080 non-null   object
#  5   location               1085 non-null   object
#  6   country                1085 non-null   object
#  7   gender                 902 non-null    object
#  8   age                    843 non-null    float64
#  9   symptom_onset          563 non-null    object
#  10  If_onset_approximated  560 non-null    float64
#  11  hosp_visit_date        507 non-null    object
#  12  exposure_start         128 non-null    object
#  13  exposure_end           341 non-null    object
# ...

# %%
COV19_WORLD.keys()
# Out:
# Index(['id', 'case_in_country', 'reporting date', 'Unnamed: 3', 'summary',
#        'location', 'country', 'gender', 'age', 'symptom_onset',
#        'If_onset_approximated', 'hosp_visit_date', 'exposure_start',
#        'exposure_end', 'visiting Wuhan', 'from Wuhan', 'death', 'recovered',
#        'symptom', 'source', 'link', 'Unnamed: 21', 'Unnamed: 22',
#        'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26'],
#       dtype='object')

# %%
COV19_WORLD[['reporting date', 'location', 'country', 'gender', 'age', 'death', 'recovered']]
# Out:
#      reporting date             location      country  gender   age death  \
# 0         1/20/2020  Shenzhen, Guangdong        China    male  66.0     0
# 1         1/20/2020             Shanghai        China  female  56.0     0
# 2         1/21/2020             Zhejiang        China    male  46.0     0
# 3         1/21/2020              Tianjin        China  female  60.0     0
# 4         1/21/2020              Tianjin        China    male  58.0     0
# ...             ...                  ...          ...     ...   ...   ...
# 1080      2/25/2020            Innsbruck      Austria     NaN  24.0     0
# 1081      2/24/2020          Afghanistan  Afghanistan     NaN  35.0     0
# 1082      2/26/2020              Algeria      Algeria    male   NaN     0
# 1083      2/25/2020              Croatia      Croatia    male   NaN     0
# 1084      2/25/2020                 Bern  Switzerland    male  70.0     0
#
#      recovered
# 0            0
# 1            0
# 2            0
# ...

# %%
COV19_WORLD_FILT_COL = COV19_WORLD[['reporting date', 'location', 'country', 'gender', 'age', 'death', 'recovered']]

COV19_WORLD_FILT_COL
# Out:
#      reporting date             location      country  gender   age death  \
# 0         1/20/2020  Shenzhen, Guangdong        China    male  66.0     0
# 1         1/20/2020             Shanghai        China  female  56.0     0
# 2         1/21/2020             Zhejiang        China    male  46.0     0
# 3         1/21/2020              Tianjin        China  female  60.0     0
# 4         1/21/2020              Tianjin        China    male  58.0     0
# ...             ...                  ...          ...     ...   ...   ...
# 1080      2/25/2020            Innsbruck      Austria     NaN  24.0     0
# 1081      2/24/2020          Afghanistan  Afghanistan     NaN  35.0     0
# 1082      2/26/2020              Algeria      Algeria    male   NaN     0
# 1083      2/25/2020              Croatia      Croatia    male   NaN     0
# 1084      2/25/2020                 Bern  Switzerland    male  70.0     0
#
#      recovered
# 0            0
# 1            0
# 2            0
# ...

# %%
COV19_WORLD_FILT_COL = COV19_WORLD_FILT_COL.rename(columns={'reporting date': 'REPORTING_DATE', 'location' : 'LOCATION', 
                                      'country' : 'COUNTRY', 'gender' : 'GENDER', 'age' : 'AGE', 
                                      'death' : 'DEATH', 'recovered' : 'RECOVERED'})

# %%
COV19_WORLD_FILT_COL
# Out:
#      REPORTING_DATE             LOCATION      COUNTRY  GENDER   AGE DEATH  \
# 0         1/20/2020  Shenzhen, Guangdong        China    male  66.0     0
# 1         1/20/2020             Shanghai        China  female  56.0     0
# 2         1/21/2020             Zhejiang        China    male  46.0     0
# 3         1/21/2020              Tianjin        China  female  60.0     0
# 4         1/21/2020              Tianjin        China    male  58.0     0
# ...             ...                  ...          ...     ...   ...   ...
# 1080      2/25/2020            Innsbruck      Austria     NaN  24.0     0
# 1081      2/24/2020          Afghanistan  Afghanistan     NaN  35.0     0
# 1082      2/26/2020              Algeria      Algeria    male   NaN     0
# 1083      2/25/2020              Croatia      Croatia    male   NaN     0
# 1084      2/25/2020                 Bern  Switzerland    male  70.0     0
#
#      RECOVERED
# 0            0
# 1            0
# 2            0
# ...

# %%
COV19_WORLD_FILT_COL.to_csv("COVID19_line_list_data_compact.csv")

# %%
COV19_WORLD_FILT_COL.to_csv("COVID19_line_list_data_compact.txt", sep='\t')

# %%
COV19_WORLD_FILT_COL.to_excel("COVID19_line_list_data_compact.xlsx")

# %%
COV19_WORLD_FILT_COL.to_json("COVID19_line_list_data_compact.json", orient='records')

# %%
pd.read_csv("COVID19_line_list_data_compact.csv")
# Out:
#       Unnamed: 0 REPORTING_DATE             LOCATION      COUNTRY  GENDER  \
# 0              0      1/20/2020  Shenzhen, Guangdong        China    male
# 1              1      1/20/2020             Shanghai        China  female
# 2              2      1/21/2020             Zhejiang        China    male
# 3              3      1/21/2020              Tianjin        China  female
# 4              4      1/21/2020              Tianjin        China    male
# ...          ...            ...                  ...          ...     ...
# 1080        1080      2/25/2020            Innsbruck      Austria     NaN
# 1081        1081      2/24/2020          Afghanistan  Afghanistan     NaN
# 1082        1082      2/26/2020              Algeria      Algeria    male
# 1083        1083      2/25/2020              Croatia      Croatia    male
# 1084        1084      2/25/2020                 Bern  Switzerland    male
#
#        AGE DEATH RECOVERED
# 0     66.0     0         0
# ...

# %%
pd.read_csv("COVID19_line_list_data_compact.txt", sep='\t')
# Out:
#       Unnamed: 0 REPORTING_DATE             LOCATION      COUNTRY  GENDER  \
# 0              0      1/20/2020  Shenzhen, Guangdong        China    male
# 1              1      1/20/2020             Shanghai        China  female
# 2              2      1/21/2020             Zhejiang        China    male
# 3              3      1/21/2020              Tianjin        China  female
# 4              4      1/21/2020              Tianjin        China    male
# ...          ...            ...                  ...          ...     ...
# 1080        1080      2/25/2020            Innsbruck      Austria     NaN
# 1081        1081      2/24/2020          Afghanistan  Afghanistan     NaN
# 1082        1082      2/26/2020              Algeria      Algeria    male
# 1083        1083      2/25/2020              Croatia      Croatia    male
# 1084        1084      2/25/2020                 Bern  Switzerland    male
#
#        AGE DEATH RECOVERED
# 0     66.0     0         0
# ...

# %%
pd.read_excel("COVID19_line_list_data_compact.xlsx", sheet_name='Sheet1')
# Out:
#       Unnamed: 0 REPORTING_DATE             LOCATION      COUNTRY  GENDER  \
# 0              0      1/20/2020  Shenzhen, Guangdong        China    male
# 1              1      1/20/2020             Shanghai        China  female
# 2              2      1/21/2020             Zhejiang        China    male
# 3              3      1/21/2020              Tianjin        China  female
# 4              4      1/21/2020              Tianjin        China    male
# ...          ...            ...                  ...          ...     ...
# 1080        1080      2/25/2020            Innsbruck      Austria     NaN
# 1081        1081      2/24/2020          Afghanistan  Afghanistan     NaN
# 1082        1082      2/26/2020              Algeria      Algeria    male
# 1083        1083      2/25/2020              Croatia      Croatia    male
# 1084        1084      2/25/2020                 Bern  Switzerland    male
#
#        AGE DEATH RECOVERED
# 0     66.0     0         0
# ...

# %%
pd.read_json("COVID19_line_list_data_compact.json")
# Out:
#      REPORTING_DATE             LOCATION      COUNTRY  GENDER   AGE DEATH  \
# 0         1/20/2020  Shenzhen, Guangdong        China    male  66.0     0
# 1         1/20/2020             Shanghai        China  female  56.0     0
# 2         1/21/2020             Zhejiang        China    male  46.0     0
# 3         1/21/2020              Tianjin        China  female  60.0     0
# 4         1/21/2020              Tianjin        China    male  58.0     0
# ...             ...                  ...          ...     ...   ...   ...
# 1080      2/25/2020            Innsbruck      Austria    None  24.0     0
# 1081      2/24/2020          Afghanistan  Afghanistan    None  35.0     0
# 1082      2/26/2020              Algeria      Algeria    male   NaN     0
# 1083      2/25/2020              Croatia      Croatia    male   NaN     0
# 1084      2/25/2020                 Bern  Switzerland    male  70.0     0
#
#      RECOVERED
# 0            0
# 1            0
# 2            0
# ...

# %% [markdown]
# # Filtering

# %%
COVID19 = pd.read_csv("COVID19_line_list_data_compact.csv")

COVID19
# Out:
#       Unnamed: 0 REPORTING_DATE             LOCATION      COUNTRY  GENDER  \
# 0              0      1/20/2020  Shenzhen, Guangdong        China    male
# 1              1      1/20/2020             Shanghai        China  female
# 2              2      1/21/2020             Zhejiang        China    male
# 3              3      1/21/2020              Tianjin        China  female
# 4              4      1/21/2020              Tianjin        China    male
# ...          ...            ...                  ...          ...     ...
# 1080        1080      2/25/2020            Innsbruck      Austria     NaN
# 1081        1081      2/24/2020          Afghanistan  Afghanistan     NaN
# 1082        1082      2/26/2020              Algeria      Algeria    male
# 1083        1083      2/25/2020              Croatia      Croatia    male
# 1084        1084      2/25/2020                 Bern  Switzerland    male
#
#        AGE DEATH RECOVERED
# 0     66.0     0         0
# ...

# %%
Ages = COVID19["AGE"]

Ages.head()
# Out:
# 0    66.0
# 1    56.0
# 2    46.0
# 3    60.0
# 4    58.0
# Name: AGE, dtype: float64

# %%
type(COVID19["AGE"])
# Out:
# pandas.core.series.Series

# %%
COVID19["AGE"].shape
# Out:
# (1085,)

# %%
COVID19[["AGE", "COUNTRY"]]
# Out:
#        AGE      COUNTRY
# 0     66.0        China
# 1     56.0        China
# 2     46.0        China
# 3     60.0        China
# 4     58.0        China
# ...    ...          ...
# 1080  24.0      Austria
# 1081  35.0  Afghanistan
# 1082   NaN      Algeria
# 1083   NaN      Croatia
# 1084  70.0  Switzerland
#
# [1085 rows x 2 columns]

# %%
type(COVID19[["AGE", "COUNTRY"]])
# Out:
# pandas.core.frame.DataFrame

# %%
COVID19[["AGE", "COUNTRY"]].shape
# Out:
# (1085, 2)

# %%
COVID19_ABOVE_45 = COVID19[COVID19["AGE"] > 45]

COVID19_ABOVE_45.head()
# Out:
#    Unnamed: 0 REPORTING_DATE             LOCATION COUNTRY  GENDER   AGE DEATH  \
# 0           0      1/20/2020  Shenzhen, Guangdong   China    male  66.0     0
# 1           1      1/20/2020             Shanghai   China  female  56.0     0
# 2           2      1/21/2020             Zhejiang   China    male  46.0     0
# 3           3      1/21/2020              Tianjin   China  female  60.0     0
# 4           4      1/21/2020              Tianjin   China    male  58.0     0
#
#   RECOVERED
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
COVID19["AGE"] > 45
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1080    False
# 1081    False
# 1082    False
# 1083    False
# 1084     True
# Name: AGE, Length: 1085, dtype: bool

# %%
COVID19_ABOVE_45.shape
# Out:
# (482, 8)

# %%
COVID19[COVID19["COUNTRY"].isin(["China", "Italy"])]
# Out:
#      Unnamed: 0 REPORTING_DATE             LOCATION COUNTRY  GENDER   AGE  \
# 0             0      1/20/2020  Shenzhen, Guangdong   China    male  66.0
# 1             1      1/20/2020             Shanghai   China  female  56.0
# 2             2      1/21/2020             Zhejiang   China    male  46.0
# 3             3      1/21/2020              Tianjin   China  female  60.0
# 4             4      1/21/2020              Tianjin   China    male  58.0
# ..          ...            ...                  ...     ...     ...   ...
# 195         195      1/27/2020                Hubei   China  female  51.0
# 196         196      1/27/2020             Shandong   China    male  37.0
# 964         964      1/31/2020                 Rome   Italy    male   NaN
# 965         965      1/31/2020                 Rome   Italy  female   NaN
# 966         966       02/06/20                 Rome   Italy    male  35.0
#
#     DEATH RECOVERED
# 0       0         0
# 1       0         0
# ...

# %%
COVID19[(COVID19["COUNTRY"] == "China") | (COVID19["COUNTRY"] == "Italy")]
# Out:
#      Unnamed: 0 REPORTING_DATE             LOCATION COUNTRY  GENDER   AGE  \
# 0             0      1/20/2020  Shenzhen, Guangdong   China    male  66.0
# 1             1      1/20/2020             Shanghai   China  female  56.0
# 2             2      1/21/2020             Zhejiang   China    male  46.0
# 3             3      1/21/2020              Tianjin   China  female  60.0
# 4             4      1/21/2020              Tianjin   China    male  58.0
# ..          ...            ...                  ...     ...     ...   ...
# 195         195      1/27/2020                Hubei   China  female  51.0
# 196         196      1/27/2020             Shandong   China    male  37.0
# 964         964      1/31/2020                 Rome   Italy    male   NaN
# 965         965      1/31/2020                 Rome   Italy  female   NaN
# 966         966       02/06/20                 Rome   Italy    male  35.0
#
#     DEATH RECOVERED
# 0       0         0
# 1       0         0
# ...

# %%
AGE_NOT_NA = COVID19[COVID19["AGE"].notna()]

AGE_NOT_NA
# Out:
#       Unnamed: 0 REPORTING_DATE             LOCATION      COUNTRY  GENDER  \
# 0              0      1/20/2020  Shenzhen, Guangdong        China    male
# 1              1      1/20/2020             Shanghai        China  female
# 2              2      1/21/2020             Zhejiang        China    male
# 3              3      1/21/2020              Tianjin        China  female
# 4              4      1/21/2020              Tianjin        China    male
# ...          ...            ...                  ...          ...     ...
# 1052        1052      2/21/2020              Lebanon      Lebanon  female
# 1079        1079      2/25/2020            Innsbruck      Austria     NaN
# 1080        1080      2/25/2020            Innsbruck      Austria     NaN
# 1081        1081      2/24/2020          Afghanistan  Afghanistan     NaN
# 1084        1084      2/25/2020                 Bern  Switzerland    male
#
#        AGE DEATH RECOVERED
# 0     66.0     0         0
# ...

# %%
COUNTRY_ABOVE_45 = COVID19.loc[COVID19["AGE"] > 45, "COUNTRY"]

COUNTRY_ABOVE_45
# Out:
# 0             China
# 1             China
# 2             China
# 3             China
# 4             China
#            ...
# 1024          Spain
# 1025          Spain
# 1027          Spain
# 1028          Spain
# 1084    Switzerland
# Name: COUNTRY, Length: 482, dtype: object

# %%
COVID19.iloc[9:15, 2:6]
# Out:
#     LOCATION COUNTRY  GENDER   AGE
# 9    Beijing   China    male  56.0
# 10   Beijing   China  female  18.0
# 11   Beijing   China  female  32.0
# 12  Shandong   China    male  37.0
# 13    Yunnan   China    male  51.0
# 14   Sichuan   China    male  57.0

# %%
COVID19.sort_values(by=["AGE"])
# Out:
#       Unnamed: 0 REPORTING_DATE        LOCATION    COUNTRY  GENDER   AGE  \
# 764          764       02/10/20       Vinh Phuc    Vietnam     NaN  0.25
# 476          476       02/05/20       Singapore  Singapore    male  0.50
# 525          525      2/17/2020       Singapore  Singapore    male  1.00
# 494          494       02/10/20       Singapore  Singapore  female  2.00
# 115          115      1/25/2020  Hechi, Guangxi      China  female  2.00
# ...          ...            ...             ...        ...     ...   ...
# 1076        1076      2/25/2020         Bahrain    Bahrain    male   NaN
# 1077        1077      2/25/2020         Bahrain    Bahrain  female   NaN
# 1078        1078      2/25/2020         Bahrain    Bahrain  female   NaN
# 1082        1082      2/26/2020         Algeria    Algeria    male   NaN
# 1083        1083      2/25/2020         Croatia    Croatia    male   NaN
#
#      DEATH  RECOVERED
# 764      0  2/20/2020
# 476      0  2/21/2020
# ...

# %%
COVID19.sort_values(by=["AGE"], ascending=False)
# Out:
#       Unnamed: 0 REPORTING_DATE      LOCATION    COUNTRY  GENDER   AGE DEATH  \
# 940          940      2/22/2020     Hong Kong  Hong Kong  female  96.0     0
# 900          900       02/09/20     Hong Kong  Hong Kong  female  91.0     0
# 963          963      2/27/2020     Hong Kong  Hong Kong  female  89.0     0
# 50            50      1/22/2020  Wuhan, Hubei      China    male  89.0     1
# 51            51      1/22/2020  Wuhan, Hubei      China    male  89.0     1
# ...          ...            ...           ...        ...     ...   ...   ...
# 1076        1076      2/25/2020       Bahrain    Bahrain    male   NaN     0
# 1077        1077      2/25/2020       Bahrain    Bahrain  female   NaN     0
# 1078        1078      2/25/2020       Bahrain    Bahrain  female   NaN     0
# 1082        1082      2/26/2020       Algeria    Algeria    male   NaN     0
# 1083        1083      2/25/2020       Croatia    Croatia    male   NaN     0
#
#      RECOVERED
# 940          0
# ...

# %%
COVID19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1085 entries, 0 to 1084
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      1085 non-null   int64
#  1   REPORTING_DATE  1084 non-null   object
#  2   LOCATION        1085 non-null   object
#  3   COUNTRY         1085 non-null   object
#  4   GENDER          902 non-null    object
#  5   AGE             843 non-null    float64
#  6   DEATH           1085 non-null   object
#  7   RECOVERED       1085 non-null   object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 67.9+ KB

# %%
COVID19.dtypes
# Out:
# Unnamed: 0          int64
# REPORTING_DATE     object
# LOCATION           object
# COUNTRY            object
# GENDER             object
# AGE               float64
# DEATH              object
# RECOVERED          object
# dtype: object

# %%
COVID19["REPORTING_DATE"] = COVID19["REPORTING_DATE"].astype('datetime64[ns]')

# %%
COVID19.dtypes
# Out:
# Unnamed: 0                 int64
# REPORTING_DATE    datetime64[ns]
# LOCATION                  object
# COUNTRY                   object
# GENDER                    object
# AGE                      float64
# DEATH                     object
# RECOVERED                 object
# dtype: object

# %%
COVID19.sort_values(by=["REPORTING_DATE"])
# Out:
#       Unnamed: 0 REPORTING_DATE             LOCATION   COUNTRY  GENDER   AGE  \
# 691          691     2020-01-13             Thailand  Thailand  female  61.0
# 236          236     2020-01-15             Kanagawa     Japan    male  35.0
# 692          692     2020-01-17             Thailand  Thailand  female  74.0
# 0              0     2020-01-20  Shenzhen, Guangdong     China    male  66.0
# 1              1     2020-01-20             Shanghai     China  female  56.0
# ...          ...            ...                  ...       ...     ...   ...
# 1029        1029     2020-02-28             Zaragoza     Spain  female  27.0
# 690          690     2020-02-28               Taiwan    Taiwan  female  55.0
# 235          235     2020-02-28                 Nice    France  female  23.0
# 868          868     2020-02-28                  UAE       UAE     NaN   NaN
# 261          261            NaT                Japan     Japan     NaN   NaN
#
#      DEATH  RECOVERED
# ...

# %%
COVID19.sort_values(by=["REPORTING_DATE"], ascending=False)
# Out:
#       Unnamed: 0 REPORTING_DATE            LOCATION      COUNTRY  GENDER  \
# 690          690     2020-02-28              Taiwan       Taiwan  female
# 1029        1029     2020-02-28            Zaragoza        Spain  female
# 843          843     2020-02-28  Baden-Wuerttemberg      Germany    male
# 844          844     2020-02-28  Baden-Wuerttemberg      Germany    male
# 845          845     2020-02-28  Baden-Wuerttemberg      Germany    male
# ...          ...            ...                 ...          ...     ...
# 543          543     2020-01-20         South Korea  South Korea  female
# 692          692     2020-01-17            Thailand     Thailand  female
# 236          236     2020-01-15            Kanagawa        Japan    male
# 691          691     2020-01-13            Thailand     Thailand  female
# 261          261            NaT               Japan        Japan     NaN
#
#        AGE DEATH  RECOVERED
# 690   55.0     0          0
# 1029  27.0     0          0
# ...

# %%
COVID19.sort_values(by=["REPORTING_DATE", "AGE"])
# Out:
#      Unnamed: 0 REPORTING_DATE     LOCATION      COUNTRY  GENDER   AGE DEATH  \
# 691         691     2020-01-13     Thailand     Thailand  female  61.0     0
# 236         236     2020-01-15     Kanagawa        Japan    male  35.0     0
# 692         692     2020-01-17     Thailand     Thailand  female  74.0     0
# 543         543     2020-01-20  South Korea  South Korea  female  35.0     0
# 1             1     2020-01-20     Shanghai        China  female  56.0     0
# ..          ...            ...          ...          ...     ...   ...   ...
# 985         985     2020-02-28           UK           UK     NaN   NaN     0
# 986         986     2020-02-28           UK           UK     NaN   NaN     0
# 987         987     2020-02-28        Wales           UK  female   NaN     0
# 988         988     2020-02-28           UK           UK    male   NaN     0
# 261         261            NaT        Japan        Japan     NaN   NaN     0
#
#      RECOVERED
# 691          0
# ...

# %%
COVID19.sort_values(by=["REPORTING_DATE", "AGE"] , ascending=[False, True])
# Out:
#       Unnamed: 0 REPORTING_DATE             LOCATION   COUNTRY  GENDER   AGE  \
# 235          235     2020-02-28                 Nice    France  female  23.0
# 731          731     2020-02-28             Thailand  Thailand    male  25.0
# 1026        1026     2020-02-28            Andalusia     Spain  female  25.0
# 1029        1029     2020-02-28             Zaragoza     Spain  female  27.0
# 1021        1021     2020-02-28            Andalusia     Spain    male  28.0
# ...          ...            ...                  ...       ...     ...   ...
# 0              0     2020-01-20  Shenzhen, Guangdong     China    male  66.0
# 692          692     2020-01-17             Thailand  Thailand  female  74.0
# 236          236     2020-01-15             Kanagawa     Japan    male  35.0
# 691          691     2020-01-13             Thailand  Thailand  female  61.0
# 261          261            NaT                Japan     Japan     NaN   NaN
#
#      DEATH  RECOVERED
# ...

# %%
COVID19_GROUPBY_COUNTRY = COVID19.groupby("COUNTRY")

# %%
COVID19_GROUPBY_COUNTRY["COUNTRY"].count()
# Out:
# COUNTRY
# Afghanistan      1
# Algeria          1
# Australia       15
# Austria          2
# Bahrain         17
# Belgium          1
# Cambodia         1
# Canada          12
# China          197
# Croatia          1
# Egypt            1
# Finland          1
# France          39
# Germany         54
# Hong Kong       94
# India            3
# Iran            18
# Israel           1
# Italy            3
# Japan          190
# Kuwait           9
# Lebanon          1
# Malaysia        23
# Nepal            1
# Phillipines      3
# Russia           2
# Singapore       93
# South Korea    114
# Spain           34
# Sri Lanka        1
# Sweden           1
# Switzerland      1
# Taiwan          34
# Thailand        41
# UAE             21
# UK              20
# USA             18
# Vietnam         16
# Name: COUNTRY, dtype: int64

# %%
COVID19_GROUPBY_COUNTRY[["COUNTRY", "AGE"]].mean()
# Out:
#                    AGE
# COUNTRY
# Afghanistan  35.000000
# Algeria            NaN
# Australia    42.000000
# Austria      24.000000
# Bahrain            NaN
# Belgium            NaN
# Cambodia     60.000000
# Canada       42.583333
# China        49.000000
# Croatia            NaN
# Egypt              NaN
# Finland      32.000000
# France       46.611111
# Germany      40.214286
# Hong Kong    56.075269
# India              NaN
# Iran               NaN
# Israel             NaN
# Italy        35.000000
# Japan        55.462366
# Kuwait             NaN
# Lebanon      45.000000
# Malaysia     41.304348
# Nepal        32.000000
# Phillipines  47.333333
# Russia             NaN
# Singapore    43.516667
# South Korea  47.641304
# Spain        43.809524
# Sri Lanka    40.000000
# Sweden       25.000000
# Switzerland  70.000000
# Taiwan       51.935484
# Thailand     48.166667
# UAE          44.666667
# UK           53.000000
# USA          50.000000
# Vietnam      36.525000

# %%
COVID19_GROUPBY_COUNTRY = COVID19.groupby("COUNTRY", sort=False)

# %%
COVID19_GROUPBY_COUNTRY[["COUNTRY", "AGE"]].mean()
# Out:
#                    AGE
# COUNTRY
# China        49.000000
# France       46.611111
# Japan        55.462366
# Malaysia     41.304348
# Nepal        32.000000
# Singapore    43.516667
# South Korea  47.641304
# Taiwan       51.935484
# Thailand     48.166667
# USA          50.000000
# Vietnam      36.525000
# Australia    42.000000
# Canada       42.583333
# Cambodia     60.000000
# Sri Lanka    40.000000
# Germany      40.214286
# UAE          44.666667
# Hong Kong    56.075269
# Italy        35.000000
# Russia             NaN
# UK           53.000000
# India              NaN
# Phillipines  47.333333
# Finland      32.000000
# Spain        43.809524
# Sweden       25.000000
# Belgium            NaN
# Egypt              NaN
# Iran               NaN
# Israel             NaN
# Lebanon      45.000000
# Kuwait             NaN
# Bahrain            NaN
# Austria      24.000000
# Afghanistan  35.000000
# Algeria            NaN
# Croatia            NaN
# Switzerland  70.000000

# %%
COVID19_GROUPBY_COUNTRY.get_group('Italy')
# Out:
#      Unnamed: 0 REPORTING_DATE LOCATION  GENDER   AGE DEATH RECOVERED
# 964         964     2020-01-31     Rome    male   NaN     0         0
# 965         965     2020-01-31     Rome  female   NaN     0         0
# 966         966     2020-02-06     Rome    male  35.0     0         0

# %%
COVID19_GROUPBY_COUNTRY_GENDER = COVID19.groupby(["COUNTRY", "GENDER"])

# %%
COVID19_GROUPBY_COUNTRY_GENDER["GENDER"].count() \
                                        .reset_index(name='count') \
                                        .sort_values(['count'], \
                                                     ascending=False)
# Out:
#         COUNTRY  GENDER  count
# 9         China    male    124
# 23        Japan    male    121
# 8         China  female     73
# 22        Japan  female     64
# 34    Singapore    male     54
# 35  South Korea  female     49
# 17    Hong Kong    male     47
# 16    Hong Kong  female     47
# 36  South Korea    male     43
# 33    Singapore  female     37
# 15      Germany    male     21
# 42       Taiwan  female     18
# 38        Spain    male     18
# 43       Taiwan    male     16
# 13       France    male     13
# 26     Malaysia  female     13
# 44     Thailand  female     11
# 3       Bahrain  female     11
# 27     Malaysia    male     10
# 2     Australia    male      9
# 6        Canada  female      8
# 45     Thailand    male      8
# 12       France  female      7
# 37        Spain  female      7
# 14      Germany  female      7
# 51          USA    male      6
# 1     Australia  female      6
# 49           UK    male      5
# 52      Vietnam  female      4
# ...

# %%
COVID19
# Out:
#       Unnamed: 0 REPORTING_DATE             LOCATION      COUNTRY  GENDER  \
# 0              0     2020-01-20  Shenzhen, Guangdong        China    male
# 1              1     2020-01-20             Shanghai        China  female
# 2              2     2020-01-21             Zhejiang        China    male
# 3              3     2020-01-21              Tianjin        China  female
# 4              4     2020-01-21              Tianjin        China    male
# ...          ...            ...                  ...          ...     ...
# 1080        1080     2020-02-25            Innsbruck      Austria     NaN
# 1081        1081     2020-02-24          Afghanistan  Afghanistan     NaN
# 1082        1082     2020-02-26              Algeria      Algeria    male
# 1083        1083     2020-02-25              Croatia      Croatia    male
# 1084        1084     2020-02-25                 Bern  Switzerland    male
#
#        AGE DEATH RECOVERED
# 0     66.0     0         0
# ...
